# %%
#linear regression
# data:

#x(week)                                                  y(sales in thousand)
# ------------------------------------------------------------------------------
# 1                                                         1.2
# 2                                                         1.8
# 3                                                         2.5
# 4                                                         3.2
# 5                                                         3.8
#Linear Regeression formula--> y=a0+a1*x

#a1-->((meanof(x*y))-(meanof(x)*meanof(y)))/meanof(x^2)-((x)^2)
#a0=mean(y)-a1*meanof(x)
#              x       y         x^2          x*y
#------------------------------------------------------
#              1       1.2        1            1.2   
#              2       1.8        4            3.6
#              3       2.5        9            7.5
#              4       3.2        16           12.8
#              5       3.8        25           19
#-------------------------------------------------------
#      sum:   15       12.5       55           44.1
#  average: x=3       y=2.5    x^2=11        x*y=8.8
#a1=0.66
#a0=0.54

#the sales for 3r week
#y=a0+a1*x
#y=0.66+0.54*3
#y=2.52

#the sales for 7r week
#y=a0+a1*x
#y=0.66+0.54*7
#y=5.16

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("C:\\Users\\prasa\\Desktop\\Linear_regr_Salary_dataset.csv")

# %%
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.shape
# Out:
# (30, 3)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=df[['YearsExperience']]
x
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
y=df[['Salary']]
y
# Out:
#       Salary
# 0    39344.0
# 1    46206.0
# 2    37732.0
# 3    43526.0
# 4    39892.0
# 5    56643.0
# 6    60151.0
# 7    54446.0
# 8    64446.0
# 9    57190.0
# 10   63219.0
# 11   55795.0
# 12   56958.0
# 13   57082.0
# 14   61112.0
# 15   67939.0
# 16   66030.0
# 17   83089.0
# 18   81364.0
# 19   93941.0
# 20   91739.0
# 21   98274.0
# 22  101303.0
# 23  113813.0
# 24  109432.0
# 25  105583.0
# 26  116970.0
# 27  112636.0
# 28  122392.0
# 29  121873.0

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(x_test)
pred
# Out:
# array([[115942.4335911 ],
#        [ 72303.50533756],
#        [102943.60389856],
#        [ 76017.45667829],
#        [ 56519.21213947],
#        [ 61161.65131538],
#        [122441.84843738],
#        [107586.04307447],
#        [ 63947.11482092],
#        [ 37020.96760065],
#        [ 47234.33378765],
#        [ 74160.48100792]])

# %%
y_pred=model.predict(x_test)

# %%
y_pred.shape
# Out:
# (12, 1)

# %%
y_test=np.array([y_test])

# %%
y_test
# Out:
# array([[[112636.],
#         [ 67939.],
#         [113813.],
#         [ 83089.],
#         [ 64446.],
#         [ 57190.],
#         [122392.],
#         [109432.],
#         [ 56958.],
#         [ 39344.],
#         [ 39892.],
#         [ 66030.]]])

# %%
acc=accuracy_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 acc=accuracy_score(y_test,y_pred)
#
# File ~\Contacts\anaconda\lib\site-packages\sklearn\utils\_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
# --> 192     return func(*args, **kwargs)
#     193 except InvalidParameterError as e:
#     194     # When the function is just a wrapper around an estimator, we allow
#     195     # the function to delegate validation to the estimator, but we replace
#     196     # the name of the estimator by the name of the function in the error
#     197     # message to avoid confusion.
#     198     msg = re.sub(
#     199         r"parameter of \w+ must be",
# ...

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 2
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 mse=mean_squared_error(y_test,y_pred)
#       3 mse
#
# File ~\Contacts\anaconda\lib\site-packages\sklearn\metrics\_regression.py:442, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     382 def mean_squared_error(
#     383     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     384 ):
#     385     """Mean squared error regression loss.
#     386
#     387     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#     445     check_consistent_length(y_true, y_pred, sample_weight)
# ...

# %%
df=pd.read_csv("C:\\Users\\prasa\\Desktop\\LR_Student_Performance.csv")
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.shape
# Out:
# (10000, 6)

# %%
duplicate_rows=df.duplicated()

# %%
duplicate_rows.sum()
# Out:
# 127

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (9873, 6)

# %%
response=df['Performance Index']

# %%
response.dtype
# Out:
# dtype('float64')

# %%
plt.plot(response.index,response)
plt.xlabel('index')
plt.ylabel('Performance Index')
# Out:
# Text(0, 0.5, 'Performance Index')

# %%
import seaborn as sns
sns.jointplot(x=response.index,y='Performance Index',data=df,kind='hex')

# %%
sns.violinplot(response)
# Out:
# <Axes: >

# %%
x=df['Performance Index'].max()
x
# Out:
# 100.0

# %%
y=df['Performance Index'].min()
y
# Out:
# 10.0

# %%
df['Hours Studied'].value_counts()
# Out:
# 1    1133
# 6    1122
# 7    1118
# 3    1110
# 9    1099
# 2    1077
# 8    1074
# 4    1071
# 5    1069
# Name: Hours Studied, dtype: int64

# %%
(df['Performance Index']==x).sum()
# Out:
# 3

# %%
(df['Performance Index']==y).sum()
# Out:
# 1

# %%
df['Hours Studied'].value_counts()
# Out:
# 1    1133
# 6    1122
# 7    1118
# 3    1110
# 9    1099
# 2    1077
# 8    1074
# 4    1071
# 5    1069
# Name: Hours Studied, dtype: int64

# %%
df['Hours Studied'].unique()
# Out:
# array([7, 4, 8, 5, 3, 6, 2, 1, 9], dtype=int64)

# %%
s=df['Hours Studied']
s
# Out:
# 0       7
# 1       4
# 2       8
# 3       5
# 4       7
#        ..
# 9995    1
# 9996    7
# 9997    6
# 9998    9
# 9999    7
# Name: Hours Studied, Length: 9873, dtype: int64

# %%
import seaborn as sns
sns.histplot(s,color='green')
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Count'>

# %%
x=df['Performance Index'].value_counts()
#sns.histplot(x,color='blue')
x
# Out:
# 67.0     182
# 45.0     181
# 56.0     179
# 49.0     177
# 40.0     176
#         ...
# 14.0       7
# 99.0       6
# 11.0       5
# 100.0      3
# 10.0       1
# Name: Performance Index, Length: 91, dtype: int64

# %%
sns.histplot(x,color='blue')
# Out:
# <Axes: xlabel='Performance Index', ylabel='Count'>

# %%
plt.pie(x)
plt.show()

# %%
sns.boxplot(x=df['Hours Studied'],y=df['Performance Index'])
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
sns.histplot(df['Extracurricular Activities'])
# Out:
# <Axes: xlabel='Extracurricular Activities', ylabel='Count'>
